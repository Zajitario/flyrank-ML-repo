# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Zajitario/flyrank-ML-repo/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **Ranking Signal Analysis** — I chose Ranking Signal Analysis because I want to understand which metrics in the dataset (CTR, average position, impressions, content age) appear to correlate with page performance. This helps prioritize which signals tu use in future models or decisions.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# The decision my work improves is which content should be refreshed or prioritized for optimization. The action is taken by the SEO and content team, who decide where to invest effort. A wrong recommendation would mean refreshing low-value pages while ignoring high-potential ones, which could cost lost traffic, wasted resources, and missed opportunities to improve visibility.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# A quick look at the starter dataset shows meaningful variation in key signals. The average CTR is around 0.51, while the average position is about 16.3. In addition, more than 13,000 pages have over 1,000 impressions. These numbers confirm that there is enough data to explore which signals are most associated with visibility and engagement, making this lane worth the next seven weeks.

# %%
import os
import pandas as pd

os.chdir("/content/flyrank-ML-repo")

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Average CTR:", df["ctr"].mean())
print("Average position:", df["avg_position"].mean())
print("Pages with impressions > 1000:", (df["impressions_90d"] > 1000).sum())
# Out:
# Average CTR: 0.5107333333333334
# Average position: 16.342380000000002
# Pages with impressions > 1000: 13509

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# My work can show observed correlations and directional evidence between signals such as CTR, impressions, and average position. It can provide decision-support by highlighting which pages may benefit from refresh or optimization. However, my work cannot prove causality, cannot predict Google’s algorithm, and cannot guarantee future performance. The results are observational and should be used as guidance, not as definitive proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [✔] Every section above is filled — markdown thinking AND the code that backs it
# - [✔] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [✔] No client names, URLs, or private queries anywhere
# - [✔] My claims use careful words: observed, measured, directional, decision-support
# - [✔] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
